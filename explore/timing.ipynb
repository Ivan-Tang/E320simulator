# %%
import pandas as pd
df = pd.read_parquet('/Users/IvanTang/hep/data_Run502/simulation/timing_data_test.parquet')
df
# Out:
#       event_index  baseline_time_ms  hough_time_ms  kalman_time_ms  \
# 0               0          0.616166      10.632625       20.555625
# 1               1          0.474583      11.375834        8.334667
# 2               2          0.214000      10.490708        6.165333
# 3               3          0.159125       9.607792        4.525750
# 4               4          0.186875       9.306917        4.545917
# ...           ...               ...            ...             ...
# 9995         9995          0.307500      10.236042        4.614167
# 9996         9996          0.170208       9.052000        4.411000
# 9997         9997          0.184833       9.292000       12.513125
# 9998         9998          0.181083       9.060792        6.089833
# 9999         9999          0.180458       8.920667        4.462167
#
#       gnn_time_ms
# 0       12.403542
# 1        1.327125
# 2        0.938000
# 3        1.029042
# 4        0.766583
# ...           ...
# 9995     0.896917
# ...

# %%
import numpy as np
print(f'{np.mean(df['baseline_time_ms'])}, {np.mean(df['gnn_time_ms'])}, {np.mean(df['hough_time_ms'])}')
# Out:
# 0.19294148826447782, 0.8618604440562194, 9.435424122956466
